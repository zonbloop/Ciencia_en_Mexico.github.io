# %% [markdown]
# # Mexico and Science

# %% [markdown]
# In this project we will see what is the perception of science in Mexico.

# %% [markdown]
# ## Data overview

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
root = "./enpecyt/conjunto de datos/"
cuestio1=pd.read_csv(root+"tr_cbasico1.csv")
cuestio2=pd.read_csv(root+"tr_cbasico2.csv")

socio1=pd.read_csv(root+"tr_csocio1.csv")
socio2=pd.read_csv(root+"tr_csocio1.csv")
socio3=pd.read_csv(root+"tr_csocio1.csv")

# %% [markdown]
# We only want a few data in order to answer the questions

# %%
cuestio1.columns[1:7]
# Out:
# Index(['PER', 'ENT', 'CON', 'V_SEL', 'N_HOG', 'N_REN'], dtype='object')

# %% [markdown]
# In order to join all the different tables, we should create an ID:

# %%
cuestio1["ID"] = cuestio1["CD_A"].astype(str)  
for index in cuestio1.columns[1:7]:
    if index!="N_REN":
        cuestio1["ID"] += cuestio1[index].astype(str)+"_"
    else:
        cuestio1["ID"] += cuestio1[index].astype(str)

cuestio2["ID"] = cuestio2["CD_A"].astype(str)  
for index in cuestio2.columns[1:7]:
    if index!="N_REN":
        cuestio2["ID"] += cuestio2[index].astype(str)+"_"
    else:
        cuestio2["ID"] += cuestio2[index].astype(str)

# %%
cuestio1["ID"]
# Out:
# 0        141117_1_40018_3_1_1
# 1        141117_1_40018_4_1_1
# 2        141117_1_40018_2_1_1
# 3        141117_1_40018_1_1_3
# 4        141117_1_40018_5_1_2
#                 ...
# 2848    321117_32_40345_2_1_2
# 2849    321117_32_40390_2_1_2
# 2850    321117_32_40390_4_1_2
# 2851    321117_32_40390_5_1_1
# 2852    321117_32_40390_3_1_1
# Name: ID, Length: 2853, dtype: object

# %%
cuestio1.shape
# Out:
# (2853, 237)

# %%
cuestio2.shape
# Out:
# (2853, 202)

# %%
socio1.columns[1:7]
# Out:
# Index(['PER', 'ENT', 'CON', 'V_SEL', 'N_HOG', 'N_REN'], dtype='object')

# %%
socio1["ID"] = socio1["CD_A"].astype(str)  
for index in socio1.columns[1:7]:
    if index!="N_REN":
        socio1["ID"] += socio1[index].astype(str)+"_"
    else:
        socio1["ID"] += socio1[index].astype(str)

socio2["ID"] = socio2["CD_A"].astype(str)  
for index in socio2.columns[1:7]:
    if index!="N_REN":
        socio2["ID"] += socio2[index].astype(str)+"_"
    else:
        socio2["ID"] += socio2[index].astype(str)
        
socio3["ID"] = socio3["CD_A"].astype(str)  
for index in socio3.columns[1:7]:
    if index!="N_REN":
        socio3["ID"] += socio3[index].astype(str)+"_"
    else:
        socio3["ID"] += socio3[index].astype(str)

# %%
socio = pd.concat([socio1,socio2,socio3])
socio = socio[["ID","SEX","EDA","FAC18"]]

# %%
cuestio = cuestio1.join(cuestio2.set_index(["ID"]),on = ["ID"],how = "inner", rsuffix="copia")
cuestio = cuestio.join(socio.set_index(["ID"]),on=["ID"],how="inner")

# %% [markdown]
# We take an inner join because we want the demographic variables as sex, age and the decision factor (how many people represent such person)

# %%
list(cuestio.columns)
# Out:
# ['CD_A',
#  'PER',
#  'ENT',
#  'CON',
#  'V_SEL',
#  'N_HOG',
#  'N_REN',
#  'S3P1',
#  'S3P1_2',
#  'S3P2',
#  'S3P2_ES',
#  'S3P3',
#  'S3P4_1',
#  'S3P4_2',
#  'S3P4_3',
#  'S3P4_4',
#  'S3P4_5',
#  'S3P4_6',
#  'S3P4_7',
#  'S3P5',
#  'S3P5_ES',
#  'S3P6',
#  'S3P7',
#  'S3P7_1_1',
#  'S3P7_1_2',
#  'S3P7_1_3',
#  'S3P7_1_4',
#  'S3P7_1_5',
#  'S3P7_2_1',
#  'S3P7_2_2',
#  'S3P7_2_3',
#  'S3P7_2_4',
#  'S3P7_2_5',
#  'S3P8',
#  'S3P9',
#  'S3P10',
#  'S3P11_ES',
#  'S3P12_C',
#  'S3P12_ES',
#  'S3P13_ES',
#  'S3P14_C',
#  'S3P14_ES',
#  'S3P15',
#  'S4P1_1',
#  'S4P1_2',
#  'S4P1_3',
#  'S4P1_4',
#  'S4P1_5',
#  'S4P1_6',
#  'S4P1_7',
#  'S4P1_8',
#  'S4P1_1_1A',
#  'S4P1_1_2A',
#  'S4P1_1_3A',
#  'S4P1_1_4A',
#  'S4P1_1_5A',
#  'S4P1_1_6A',
#  'S4P1_1_7A',
#  'S4P1_1_8A',
#  'S4P1_1_ESA',
#  'S4P1_1_1B',
#  'S4P1_1_2B',
#  'S4P1_1_3B',
#  'S4P1_1_4B',
#  'S4P1_1_5B',
#  'S4P1_1_6B',
#  'S4P1_1_7B',
#  'S4P1_1_8B',
#  'S4P1_1_ESB',
#  'S4P1_1_1C',
#  'S4P1_1_2C',
#  'S4P1_1_3C',
#  'S4P1_1_4C',
#  'S4P1_1_5C',
#  'S4P1_1_6C',
#  'S4P1_1_7C',
#  'S4P1_1_8C',
#  'S4P1_1_ESC',
#  'S4P1_2_1',
#  'S4P1_2_2',
#  'S4P1_2_3',
#  'S4P1_2_4',
#  'S4P1_2_5',
#  'S4P1_2_6',
#  'S4P1_2_7',
#  'S4P2_1',
#  'S4P2_2',
#  'S4P2_3',
#  'S4P2_4',
#  'S4P2_5',
#  'S4P2_6',
#  'S4P2_7',
#  'S4P2_8',
#  'S4P3_1',
#  'S4P3_2',
#  'S4P3_3',
#  'S4P3_4',
#  'S4P3_5',
#  'S4P3_6',
#  'S4P3_7',
#  'S4P3_8',
#  'S4P3_9',
#  'S4P4',
#  'S4P4_1',
#  'S4P4_2',
#  'S4P4_3',
#  'S4P4_4',
#  'S4P5',
#  'S4P5_1',
#  'S4P5_2',
#  'S4P5_3',
#  'S4P5_4',
#  'S4P6',
#  'S4P6_1',
#  'S4P6_2',
#  'S4P6_3',
#  'S4P6_4',
#  'S4P6_5',
#  'S4P7',
#  'S4P7_1',
#  'S4P7_2',
#  'S4P7_3',
#  'S4P7_4',
#  'S4P7_5',
#  'S4P8',
#  'S4P8_1_1',
#  'S4P8_1_2',
#  'S4P8_1_ES',
#  'S4P9',
#  'S4P10',
#  'S4P10_1',
#  'S4P11_1',
#  'S4P11_2',
#  'S4P11_3',
#  'S4P11_4',
#  'S4P11_5',
#  'S4P11_6',
#  'S4P11_7',
#  'S4P11_8',
#  'S4P11_9',
#  'S4P11_10',
#  'S4P11_11',
#  'S4P11_12',
#  'S4P11_13',
#  'S4P11_14',
#  'S4P11_15',
#  'S4P11_16',
#  'S4P11_17',
#  'S4P11_ES',
#  'S4P12_1',
#  'S4P12_2',
#  'S4P12_3',
#  'S4P12_4',
#  'S4P12_5',
#  'S4P12_6',
#  'S4P12_7',
#  'S4P12_8',
#  'S4P12_9',
#  'S4P12_10',
#  'S4P12_1_1',
#  'S4P12_1_2',
#  'S4P12_1_3',
#  'S4P12_1_4',
#  'S4P12_1_5',
#  'S4P12_1_6',
#  'S4P12_1_7',
#  'S4P12_1_8',
#  'S4P12_1_9',
#  'S4P12_1_10',
#  'S4P12_1_ES',
#  'S4P12_2_1',
#  'S4P12_2_2',
#  'S4P12_2_3',
#  'S4P12_2_4',
#  'S4P12_2_5',
#  'S4P12_2_6',
#  'S4P12_2_7',
#  'S4P12_2_8',
#  'S4P12_2_ES',
#  'S4P13_1',
#  'S4P13_2',
#  'S4P13_3',
#  'S4P14_1',
#  'S4P14_2',
#  'S4P14_3',
#  'S4P14_4',
#  'S4P14_5',
#  'S4P14_6',
#  'S4P14_7',
#  'S4P14_8',
#  'S4P14_9',
#  'S4P14_10',
#  'S4P14_11',
#  'S4P14_12',
#  'S4P14_13',
#  'S4P14_14',
#  'S4P14_15',
#  'S4P14_16',
#  'S4P14_17',
#  'S4P15_1',
#  'S4P15_2',
#  'S4P15_3',
#  'S4P15_4',
#  'S4P15_5',
#  'S4P15_6',
#  'S4P15_7',
#  'S4P15_8',
#  'S4P15_9',
#  'S4P15_10',
#  'S4P15_11',
#  'S4P15_12',
#  'S4P15_13',
#  'S4P15_14',
#  'S4P15_15',
#  'S4P16_1',
#  'S4P16_2',
#  'S4P16_3',
#  'S4P16_4',
#  'S4P16_5',
#  'S4P16_6',
#  'S4P16_7',
#  'S4P17_1',
#  'S4P17_2',
#  'S4P17_3',
#  'S4P17_4',
#  'S4P17_5',
#  'S4P17_6',
#  'S4P17_7',
#  'S4P17_8',
#  'S4P17_9',
#  'S4P17_10',
#  'S4P17_11',
#  'S4P17_12',
#  'S4P17_13',
#  'S4P17_14',
#  'FAC',
#  'ID',
#  'CD_Acopia',
#  'PERcopia',
#  'ENTcopia',
#  'CONcopia',
#  'V_SELcopia',
#  'N_HOGcopia',
#  'N_RENcopia',
#  'S4P18_1',
#  'S4P18_2',
#  'S4P18_3',
#  'S4P18_4',
#  'S4P18_5',
#  'S4P18_6',
#  'S4P18_7',
#  'S4P18_8',
#  'S4P18_9',
#  'S4P18_10',
#  'S4P18_11',
#  'S4P18_12',
#  'S4P18_13',
#  'S4P18_14',
#  'S4P18_15',
#  'S4P18_16',
#  'S4P18_17',
#  'S4P18_18',
#  'S4P18_19',
#  'S4P18_20',
#  'S4P19',
#  'S4P20',
#  'S4P21_1',
#  'S4P21_2',
#  'S4P21_3',
#  'S4P21_4',
#  'S4P21_5',
#  'S4P21_6',
#  'S4P21_7',
#  'S4P22_1',
#  'S4P22_2',
#  'S4P22_3',
#  'S4P22_4',
#  'S4P22_5',
#  'S4P22_6',
#  'S4P22_7',
#  'S4P22_8',
#  'S4P22_9',
#  'S4P22_10',
#  'S4P22_11',
#  'S4P22_12',
#  'S4P23_1',
#  'S4P23_2',
#  'S4P23_3',
#  'S4P23_4',
#  'S4P23_5',
#  'S4P23_6',
#  'S4P23_7',
#  'S4P23_8',
#  'S4P23_9',
#  'S4P23_10',
#  'S4P24_1',
#  'S4P24_2',
#  'S4P24_3',
#  'S4P24_4',
#  'S4P24_5',
#  'S4P24_6',
#  'S4P25_1',
#  'S4P25_2',
#  'S4P25_3',
#  'S4P25_4',
#  'S4P25_5',
#  'S4P25_6',
#  'S4P25_7',
#  'S4P25_8',
#  'S4P25_9',
#  'S4P25_10',
#  'S4P25_11',
#  'S4P25_12',
#  'S4P26_1',
#  'S4P26_2',
#  'S4P26_3',
#  'S4P26_4',
#  'S4P26_5',
#  'S4P27_1',
#  'S4P27_2',
#  'S4P27_3',
#  'S4P27_4',
#  'S4P27_5',
#  'S4P27_6',
#  'S4P27_7',
#  'S4P27_8',
#  'S4P27_9',
#  'S4P28_1',
#  'S4P28_2',
#  'S4P28_3',
#  'S4P28_4',
#  'S4P28_5',
#  'S4P28_6',
#  'S4P28_7',
#  'S4P28_8',
#  'S4P28_9',
#  'S4P29_1',
#  'S4P29_2',
#  'S4P30',
#  'S4P30_1',
#  'S4P30_2',
#  'S4P31',
#  'S4P31_1_1',
#  'S4P31_1_2',
#  'S4P31_1_3',
#  'S4P31_1_4',
#  'S4P31_1_5',
#  'S4P31_1_6',
#  'S4P31_1_7',
#  'S4P32',
#  'S4P32_1',
#  'S4P33',
#  'S5P1',
#  'S5P1_1',
#  'S5P2_1',
#  'S5P2_2',
#  'S5P2_3',
#  'S5P2_4',
#  'S5P2_5',
#  'S5P2_6',
#  'S5P2_ES',
#  'S5P3',
#  'S5P4_1',
#  'S5P4_2',
#  'S5P4_3',
#  'S5P4_4',
#  'S5P4_5',
#  'S5P4_6',
#  'S5P4_7',
#  'S5P4_8',
#  'S5P4_9',
#  'S5P4_10',
#  'S5P4_11',
#  'S5P4_12',
#  'S5P4_ES',
#  'S5P5',
#  'S5P6_1',
#  'S5P6_2',
#  'S5P6_3',
#  'S5P6_4',
#  'S5P6_5',
#  'S5P6_6',
#  'S5P6_7',
#  'S5P6_8',
#  'S5P6_9',
#  'S5P6_10',
#  'S5P6_11',
#  'S5P6_12',
#  'S5P6_13',
#  'S5P6_14',
#  'S5P7',
#  'S5P8',
#  'S5P9',
#  'S5P10_1',
#  'S5P10_2',
#  'S5P10_3',
#  'S5P10_4',
#  'S5P10_5',
#  'S5P10_6',
#  'S5P11_D1',
#  'S5P11_D2',
#  'S5P11_D3',
#  'S5P12_1',
#  'S5P12_2',
#  'S5P12_3',
#  'S5P12_4',
#  'S5P12_5',
#  'S5P12_6',
#  'S5P12_ESP',
#  'S5P13_1',
#  'S5P13_2',
#  'S5P13_3',
#  'S5P13_4',
#  'S5P13_5',
#  'S5P13_6',
#  'S5P13_7',
#  'S5P13_8',
#  'S5P13_9',
#  'S5P13_10',
#  'S5P13_11',
#  'S5P13_12',
#  'S5P13_13',
#  'S5P13_14',
#  'S5P13_15',
#  'S5P13_16',
#  'S5P13_17',
#  'S5P13_18',
#  'S5P13_19',
#  'S5P13_20',
#  'S5P13_21',
#  'S5P13_22',
#  'S5P13_23',
#  'S5P13_24',
#  'S5P13_25',
#  'S5P13_26',
#  'S5P13_27',
#  'OBS',
#  'FACcopia',
#  'SEX',
#  'EDA',
#  'FAC18']

# %%
cuestio.head(10)
# Out:
#    CD_A   PER  ENT    CON  V_SEL  N_HOG  N_REN  S3P1  S3P1_2 S3P2  ...  \
# 0    14  1117    1  40018      3      1      1   3.0     3.0  NaN  ...
# 0    14  1117    1  40018      3      1      1   3.0     3.0  NaN  ...
# 0    14  1117    1  40018      3      1      1   3.0     3.0  NaN  ...
# 1    14  1117    1  40018      4      1      1   2.0     6.0  NaN  ...
# 1    14  1117    1  40018      4      1      1   2.0     6.0  NaN  ...
# 1    14  1117    1  40018      4      1      1   2.0     6.0  NaN  ...
# 2    14  1117    1  40018      2      1      1   2.0     6.0  NaN  ...
# 2    14  1117    1  40018      2      1      1   2.0     6.0  NaN  ...
# 2    14  1117    1  40018      2      1      1   2.0     6.0  NaN  ...
# 3    14  1117    1  40018      1      1      3   4.0     3.0  NaN  ...
#
#   S5P13_23  S5P13_24  S5P13_25  S5P13_26  S5P13_27  OBS  FACcopia  SEX   EDA  \
# 0        2         2         2         2         2  NaN      5072    1  27.0
# 0        2         2         2         2         2  NaN      5072    1  27.0
# 0        2         2         2         2         2  NaN      5072    1  27.0
# 1        2         2         2         2         2  NaN      5072    1  72.0
# 1        2         2         2         2         2  NaN      5072    1  72.0
# 1        2         2         2         2         2  NaN      5072    1  72.0
# 2        2         2         2         2         2  NaN      7608    2  47.0
# 2        2         2         2         2         2  NaN      7608    2  47.0
# 2        2         2         2         2         2  NaN      7608    2  47.0
# 3        2         2         2         2         2  NaN     10144    2  51.0
#
#      FAC18
# 0   5072.0
# 0   5072.0
# 0   5072.0
# 1   5072.0
# 1   5072.0
# 1   5072.0
# 2   7608.0
# 2   7608.0
# 2   7608.0
# 3  10144.0
#
# [10 rows x 441 columns]

# %%
cuestio["FAC"].sum()
# Out:
# 38539041

# %% [markdown]
# The total population: $38,539,041$

# %% [markdown]
# What is the average grade of studies in Mexico?

# %%
data=cuestio.groupby(["S3P1"])["FAC"].sum() / cuestio["FAC"].sum()*100
data
# Out:
# S3P1
# 1.0      1.056736
# 2.0     16.634628
# 3.0     21.556657
# 4.0     27.071984
# 5.0      0.077166
# 6.0      7.888297
# 7.0     20.428017
# 8.0      0.062321
# 9.0      1.020648
# 10.0     0.132154
# Name: FAC, dtype: float64

# %%
cuestio["S3P1"].value_counts()
# Out:
# 3.0     744
# 7.0     639
# 4.0     621
# 2.0     519
# 6.0     180
# 9.0      84
# 5.0      15
# 8.0      12
# 10.0      9
# 1.0       3
# Name: S3P1, dtype: int64

# %%
label = [ r"Prescolar (1.06%) ", r"Primaria (16.63%)", r"Secundaria (21.56%)", r"Preparatoria (27.07%)", r"Normal (0.07%)",
         r"Carrera técnica (7.89%)",r"Licenciatura (20.43%)", r"Especialidad (0.06%)", r"Maestría (1.02%)", r"Doctorado (0.13%)"]
explode = (0.1, 0.2, 0.3, 0.4, 0.0, 0.0,0.5, 0.0,0.0, 0.0)

data=cuestio.groupby(["S3P1"])["FAC"].sum() / cuestio["FAC"].sum()*100

fig, ax = plt.subplots(figsize =(10, 25))
texts, autotexts = ax.pie(data,    
                          explode=None,
                          shadow = True,
                          startangle = 90, 
                          wedgeprops = { 'linewidth' : 1, 'edgecolor' : "green" }, 
                          textprops = dict(color ="magenta")) 
plt.legend(texts, label, loc="best")
plt.setp(autotexts, size = 8, weight ="bold") 
ax.set_title("Educación en México") 
  
plt.show()

# %%
100 * cuestio.groupby(["S3P1"])["FAC"].sum() / cuestio["FAC"].sum()
# Out:
# S3P1
# 1.0      1.056736
# 2.0     16.634628
# 3.0     21.556657
# 4.0     27.071984
# 5.0      0.077166
# 6.0      7.888297
# 7.0     20.428017
# 8.0      0.062321
# 9.0      1.020648
# 10.0     0.132154
# Name: FAC, dtype: float64
